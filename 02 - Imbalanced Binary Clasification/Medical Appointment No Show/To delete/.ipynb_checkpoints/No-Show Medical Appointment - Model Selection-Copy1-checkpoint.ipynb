# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os

# %%
import optuna
import scipy.stats as stats

# %%
from sklearn import metrics
from sklearn.metrics import roc_curve, roc_auc_score, confusion_matrix, classification_report
from sklearn.model_selection import cross_val_score, RandomizedSearchCV, KFold, StratifiedKFold, cross_validate
from sklearn.pipeline import Pipeline

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %% [markdown]
# # Importación de datos

# %%
# Definir la ruta común
base_path = "../Medical Appointment No Show/Proceced Datasets/"

# Función para importar DataFrames y eliminar el nombre del índice
def import_with_index(filepath):
    # Leer el CSV con el índice
    df = pd.read_csv(filepath, index_col=0)
    # Eliminar el nombre del índice
    df.index.name = None
    return df

# Importar los DataFrames de forma manual

X_train = import_with_index(os.path.join(base_path, 'X_train_pipe.csv'))
X_test = import_with_index(os.path.join(base_path, 'X_test_pipe.csv'))

X_train_trees = import_with_index(os.path.join(base_path, 'X_train_pipe_trees.csv'))
X_test_trees = import_with_index(os.path.join(base_path, 'X_test_pipe_trees.csv'))

y_train = import_with_index(os.path.join(base_path, 'y_train_pipe.csv'))
y_test = import_with_index(os.path.join(base_path, 'y_test_pipe.csv'))

# %%
X_train.head(4)
# Out:
#        Scholarship  Hipertension  Diabetes  Alcoholism  Handcap  SMS_received  \
# 64200            0             0         0           0      0.0             0
# 91954            0             0         0           0      0.0             0
# 11678            0             0         0           0      0.0             0
# 84806            0             0         0           0      0.0             1
#
#        FirstTimeAppointment  Comorbilidades  InteraccionCondicionesHandcap  \
# 64200                     1             0.0                            0.0
# 91954                     1             0.0                            0.0
# 11678                     1             0.0                            0.0
# 84806                     0             0.0                            0.0
#
#        RiesgoGeneral  ...  DayOfWeek_Tuesday  DayOfWeek_Wednesday  \
# 64200            0.0  ...                  0                    1
# 91954            0.0  ...                  0                    0
# 11678            0.0  ...                  0                    0
# 84806            0.0  ...                  1                    0
#
#        ScheduledPeriod_Noche  ScheduledPeriod_Tarde  \
# 64200                      0                      0
# 91954                      0                      0
# 11678                      0                      0
# 84806                      0                      1
#
#        Age_group_Adultos mayores (60-79)  Age_group_Adultos medios (40-59)  \
# 64200                                  0                                 0
# 91954                                  0                                 1
# 11678                                  0                                 0
# 84806                                  1                                 0
#
#        Age_group_Ancianos (80+)  Age_group_Infancia (0-6)  \
# 64200                         0                         0
# 91954                         0                         0
# 11678                         0                         0
# 84806                         0                         0
#
#        Age_group_Jóvenes adultos (20-39)  Age_group_Niñez (7-12)
# 64200                                  1                       0
# 91954                                  0                       0
# 11678                                  1                       0
# 84806                                  0                       0
#
# [4 rows x 35 columns]

# %%
y_train.head(4)
# Out:
#        No-show
# 64200        0
# 91954        0
# 11678        0
# 84806        0

# %%
all(X_train.index == y_train.index)
# Out:
# True

# %%
X_test.head(4)
# Out:
#         Scholarship  Hipertension  Diabetes  Alcoholism  Handcap  \
# 104581            0             0         0           0      0.0
# 106123            0             0         0           0      0.0
# 54961             0             0         0           0      0.0
# 40500             0             0         0           0      0.0
#
#         SMS_received  FirstTimeAppointment  Comorbilidades  \
# 104581             0                     0             0.0
# 106123             1                     0             0.0
# 54961              0                     1             0.0
# 40500              1                     0             0.0
#
#         InteraccionCondicionesHandcap  RiesgoGeneral  ...  DayOfWeek_Tuesday  \
# 104581                            0.0            0.0  ...                  0
# 106123                            0.0            0.0  ...                  0
# 54961                             0.0            0.0  ...                  0
# 40500                             0.0            0.0  ...                  0
#
#         DayOfWeek_Wednesday  ScheduledPeriod_Noche  ScheduledPeriod_Tarde  \
# 104581                    1                      0                      0
# 106123                    1                      0                      0
# 54961                     0                      0                      0
# 40500                     0                      0                      0
#
#         Age_group_Adultos mayores (60-79)  Age_group_Adultos medios (40-59)  \
# 104581                                  1                                 0
# 106123                                  0                                 0
# 54961                                   0                                 1
# 40500                                   0                                 0
#
#         Age_group_Ancianos (80+)  Age_group_Infancia (0-6)  \
# 104581                         0                         0
# 106123                         0                         0
# 54961                          0                         0
# 40500                          0                         0
#
#         Age_group_Jóvenes adultos (20-39)  Age_group_Niñez (7-12)
# 104581                                  0                       0
# 106123                                  1                       0
# 54961                                   0                       0
# 40500                                   0                       0
#
# [4 rows x 35 columns]

# %%
y_test.head(4)
# Out:
#         No-show
# 104581        0
# 106123        0
# 54961         0
# 40500         0

# %%
y_train = y_train.values.flatten()
y_test = y_test.values.flatten()

# %%
# Asegúrate de que y_train sea un Series unidimensional
if isinstance(y_train, pd.DataFrame):
    y_train = y_train.iloc[:, 0]  # Seleccionar la primera columna como un Series

# Asegúrate de que y_train sea un Series unidimensional
if isinstance(y_test, pd.DataFrame):
    y_test = y_test.iloc[:, 0]  # Seleccionar la primera columna como un Series

# %% [markdown]
# #### Analizo la importancia de las caracteristicas con Mutual information

# %%
# to obtain the mutual information values
from sklearn.feature_selection import mutual_info_classif, mutual_info_regression

# to select the features
from sklearn.feature_selection import SelectKBest, SelectPercentile

# %%
# the smaller the value of the mi, the less information we can infer from the feature about the target
mi = mutual_info_classif(
    X = X_train, 
    y = y_train,
    discrete_features = False, 
    n_neighbors=3,
    random_state=3,
)

# 1) let's capture the above array in a pandas series
# 2)add the variable names in the index
# 3) sort the features based on their mutual information value
# 4) and make a var plot

mi = pd.Series(mi)
mi.index = X_train.columns
mi.sort_values(ascending=False).plot.bar(figsize=(20, 6))
plt.ylabel('Mutual Information')
# Out:
# Text(0, 0.5, 'Mutual Information')

# %%
list_to_drop = ['Scholarship', 'DayOfWeek_Monday', 'DayOfWeek_Tuesday', 'DayOfWeek_Thursday', 'DayOfWeek_Wednesday', 'Handcap', 'Alcoholism', 
                'InteraccionCondicionesHandcap', 'WaitingTime_(0.0, 1.0]', 'WaitingTime_(1.0, 4.0]', 'WaitingTime_(4.0, 7.0]', 
                'Cluster_1', 'Cluster_2', 'Age_group_Ancianos (80+)', 'Age_group_Niñez (7-12)', 'Age_group_Infancia (0-6)',
                'ScheduledPeriod_Noche', 'Comorbilidades', 'DayOfWeek_Saturday', 'Diabetes'
               ]
X_train = X_train.drop(columns = list_to_drop)
X_test = X_test.drop(columns = list_to_drop)

# %%
# the smaller the value of the mi, the less information we can infer from the feature about the target
mi = mutual_info_classif(
    X = X_train, 
    y = y_train,
    discrete_features = False, 
    n_neighbors=3,
    random_state=3,
)

# 1) let's capture the above array in a pandas series
# 2)add the variable names in the index
# 3) sort the features based on their mutual information value
# 4) and make a var plot

mi = pd.Series(mi)
mi.index = X_train.columns
mi.sort_values(ascending=False).plot.bar(figsize=(20, 6))
plt.ylabel('Mutual Information')
# Out:
# Text(0, 0.5, 'Mutual Information')

# %%
# the smaller the value of the mi, the less information we can infer from the feature about the target
mi_trees = mutual_info_classif(
    X = X_train_trees, 
    y = y_train,
    discrete_features = False, 
    n_neighbors=3,
    random_state=3,
)

# 1) let's capture the above array in a pandas series
# 2)add the variable names in the index
# 3) sort the features based on their mutual information value
# 4) and make a var plot

mi_trees = pd.Series(mi_trees)
mi_trees.index = X_train_trees.columns
mi_trees.sort_values(ascending=False).plot.bar(figsize=(20, 6))
plt.ylabel('Mutual Information')
# Out:
# Text(0, 0.5, 'Mutual Information')

# %%
list_to_drop = ['Scholarship', 'Handcap', 'Alcoholism', 'RiesgoGeneral']
X_train_trees = X_train_trees.drop(columns = list_to_drop)
X_test_trees = X_test_trees.drop(columns = list_to_drop)

# %% [markdown]
# # Selección de modelo

# %%
def resultados(y, y_pred):
    """
    Esta función evalúa el rendimiento de un modelo de clasificación utilizando
    una matriz de confusión y un reporte de clasificación. 

    Parámetros:
    - y: array-like, valores verdaderos de las etiquetas de clase (etiquetas reales).
    - y_pred: array-like, valores predichos por el modelo (etiquetas predichas).
    """
    conf_matrix = confusion_matrix(y, y_pred, normalize='true')
    plt.figure(figsize=(4, 3))
    sns.heatmap(conf_matrix, annot=True, cmap='Blues', vmin=0, vmax=1, center=0.5)
    plt.title("Matriz de Confusión")
    plt.ylabel('Real')
    plt.xlabel('Predicho')
    plt.show()
    print(classification_report(y, y_pred))

# %%
def model_evaluation(model, X_train, y_train):
    """
    Esta función evalúa el rendimiento del modelo utilizando K-Fold Cross-Validation
    y devuelve métricas de rendimiento, así como el riesgo de sobreajuste.

    Parámetros:
    - model: el modelo a evaluar.
    - X_train: conjunto de datos de entrenamiento.
    - y_train: etiquetas del conjunto de entrenamiento.

    Retorna:
    - df: DataFrame con las métricas de rendimiento.
    - overfitting_risk: diccionario con información sobre el riesgo de sobreajuste.
    """
    # K-Fold Cross-Validation
    kf = KFold(n_splits=10, shuffle=True, random_state=42)
    
    # Estimación del error de generalización
    clf = cross_validate(
        model,
        X_train,
        y_train,
        scoring='accuracy',             # Modificar el scoring si es necesario
        return_train_score=True,
        cv=kf
    )

    # Calcular valores para el conjunto de entrenamiento
    mean_train_score = np.mean(clf['train_score'])
    std_train_score = np.std(clf['train_score'])
    
    # Calcular el intervalo para el conjunto de entrenamiento
    interval_lower_train = mean_train_score - 3 * std_train_score
    interval_upper_train = mean_train_score + 3 * std_train_score
    
    # Calcular el puntaje medio y el intervalo para el conjunto de prueba
    mean_test_score = np.mean(clf['test_score']) if 'test_score' in clf else np.nan
    std_test_score = np.std(clf['test_score']) if 'test_score' in clf else np.nan
    
    # Calcular el intervalo para el conjunto de prueba
    interval_lower_test = mean_test_score - 3 * std_test_score if not np.isnan(mean_test_score) else np.nan
    interval_upper_test = mean_test_score + 3 * std_test_score if not np.isnan(mean_test_score) else np.nan

    # Crear el DataFrame con las métricas
    df = pd.DataFrame({
        'mean': [mean_train_score, mean_test_score],
        'std': [std_train_score, std_test_score],
        'interval_lower': [interval_lower_train, interval_lower_test],
        'interval_upper': [interval_upper_train, interval_upper_test]
    }, index=['train_set', 'test_set'])

    # Prueba t para comparar las puntuaciones de entrenamiento y prueba
    t_stat, p_value = stats.ttest_ind(clf['train_score'], clf['test_score'], equal_var=False)

    # Diccionario con la probabilidad de sobreajuste
    overfitting_risk = {
        't_statistic': t_stat,
        'p_value': p_value,
        'overfitting_likelihood': 'High' if p_value < 0.10 else 'Low'
    }
    
    return df, overfitting_risk

# %%
def objective(classifier_name, trial, X_train, y_train):
    """ Optimización de hiperparámetros con Optuna. Los rangos de los hiperparámetros 
    se ajustan según el tamaño del conjunto de datos.
    """
    # Obtener el número de muestras y características
    n_samples, n_features = X_train.shape

    # Ajuste inicial según el número de características (n_features)
    if n_features <= 14:
        logit_c_range = (1e-3, 1e3)
        rf_n_estimators_range = (10, 100)
        knn_n_neighbors_range = (3, 10)
        dt_max_depth_range = (3, 10)
    elif n_features <= 30:
        logit_c_range = (1e-2, 1e2)
        rf_n_estimators_range = (50, 200)
        knn_n_neighbors_range = (3, 20)
        dt_max_depth_range = (5, 15)
    else:
        logit_c_range = (1e-1, 1e1)
        rf_n_estimators_range = (100, 500)
        knn_n_neighbors_range = (3, 50)
        dt_max_depth_range = (10, 25)

    # Ajuste según el número de muestras (n_samples)
    if n_samples < 1000:
        # Si hay menos de 1000 muestras, generalmente el modelo debe ser más simple
        rf_n_estimators_range = (10, 100)  # Menos árboles para evitar sobreajuste
        logit_c_range = (1e-3, 1e3)  # Más regularización en modelos lineales
        svc_c_range = (1e-2, 1e2)  # Regularización más fuerte
        knn_n_neighbors_range = (3, 10)  # Menos vecinos
        dt_max_depth_range = (1, 10)  # Menos profundidad en los árboles
    elif n_samples < 10000:
        # Para 1000 < n_samples < 10000, el modelo puede ser más complejo
        rf_n_estimators_range = (50, 300)  # Más árboles
        logit_c_range = (1e-2, 1e2)  # Menos regularización
        svc_c_range = (1e-1, 1e2)
        knn_n_neighbors_range = (3, 20)  # Más vecinos
        dt_max_depth_range = (1, 15)  # Mayor profundidad
    else:
        # Si tenemos más de 10000 muestras, podemos permitir más complejidad
        rf_n_estimators_range = (100, 500)  # Mucho más árboles
        logit_c_range = (1e-1, 1e1)  # Menos regularización
        svc_c_range = (1e-1, 1e3)  # Regularización más baja
        knn_n_neighbors_range = (3, 50)  # Más vecinos
        dt_max_depth_range = (5, 25)  # Más profundidad

    # Selección de parámetros según el modelo
    if classifier_name == "logit":
        logit_penalty = trial.suggest_categorical('logit_penalty', ['l1', 'l2'])
        logit_c = trial.suggest_float('logit_c', logit_c_range[0], logit_c_range[1], log=True)
        logit_solver = trial.suggest_categorical('logit_solver', ['liblinear', 'saga'])
        logit_max_iter = trial.suggest_int('logit_max_iter', 100, 500)

        model = LogisticRegression(
            penalty=logit_penalty,
            C=logit_c,
            solver=logit_solver,
            max_iter=logit_max_iter
        )

    elif classifier_name == "RF":
        rf_n_estimators = trial.suggest_int("rf_n_estimators", rf_n_estimators_range[0], rf_n_estimators_range[1])
        rf_max_depth = trial.suggest_int("rf_max_depth", 1, 30)
        rf_min_samples_split = trial.suggest_int("rf_min_samples_split", 2, 400)
        rf_min_samples_leaf = trial.suggest_int("rf_min_samples_leaf", 1, 400)
        rf_max_features = trial.suggest_categorical("rf_max_features", [None, 'sqrt', 'log2'])
        rf_bootstrap = trial.suggest_categorical('rf_bootstrap', [True, False])

        model = RandomForestClassifier(
            n_estimators=rf_n_estimators,
            max_depth=rf_max_depth,
            min_samples_split=rf_min_samples_split,
            min_samples_leaf=rf_min_samples_leaf,
            max_features=rf_max_features,
            bootstrap=rf_bootstrap,
            random_state=42,
            n_jobs=-1
        )

    elif classifier_name == "dt":
        dt_max_depth = trial.suggest_int("dt_max_depth", dt_max_depth_range[0], dt_max_depth_range[1])
        dt_min_samples_split = trial.suggest_int("dt_min_samples_split", 2, 400)
        dt_min_samples_leaf = trial.suggest_int("dt_min_samples_leaf", 1, 400)
        dt_criterion = trial.suggest_categorical("dt_criterion", ["gini", "entropy"])

        model = DecisionTreeClassifier(
            max_depth=dt_max_depth,
            min_samples_split=dt_min_samples_split,
            min_samples_leaf=dt_min_samples_leaf,
            criterion=dt_criterion,
            random_state=42
        )

    elif classifier_name == "svc":
        svc_c = trial.suggest_float('svc_c', svc_c_range[0], svc_c_range[1], log=True)
        svc_kernel = trial.suggest_categorical('svc_kernel', ['linear', 'poly'])
        svc_gamma = trial.suggest_categorical('svc_gamma', ['scale', 'auto'])
        svc_degree = trial.suggest_int('svc_degree', 2, 4)

        model = SVC(
            C=svc_c,
            kernel=svc_kernel,
            gamma=svc_gamma,
            degree=svc_degree,
            random_state=42
        )

    elif classifier_name == "Naive":
        naive_var_smoothing = trial.suggest_float('naive_var_smoothing', 1e-3, 1e0, log=True)

        model = GaussianNB(var_smoothing=naive_var_smoothing)

    elif classifier_name == "Knn":
        knn_n_neighbors = trial.suggest_int('knn_n_neighbors', knn_n_neighbors_range[0], knn_n_neighbors_range[1], step=2)
        knn_weights = trial.suggest_categorical('knn_weights', ['uniform', 'distance'])
        knn_p = trial.suggest_int('knn_p', 1, 2)

        model = KNeighborsClassifier(
            n_neighbors=knn_n_neighbors,
            weights=knn_weights,
            p=knn_p
        )

    elif classifier_name == "gbm":
        gbm_n_estimators = trial.suggest_int("gbm_n_estimators", 10, 50)
        gbm_learning_rate = trial.suggest_float("gbm_learning_rate", 0.01, 0.2)
        gbm_max_depth = trial.suggest_int("gbm_max_depth", 1, 25)
        gbm_min_samples_split = trial.suggest_int("gbm_min_samples_split", 2, 100)
        gbm_min_samples_leaf = trial.suggest_int("gbm_min_samples_leaf", 1, 200)
        gbm_max_features = trial.suggest_categorical("gbm_max_features", ['sqrt', 'log2', None])

        model = GradientBoostingClassifier(
            n_estimators=gbm_n_estimators,
            learning_rate=gbm_learning_rate,
            max_depth=gbm_max_depth,
            min_samples_split=gbm_min_samples_split,
            min_samples_leaf=gbm_min_samples_leaf,
            max_features=gbm_max_features,
            random_state=42
        )

    # Llamada a la función de evaluación del modelo
    df, overfitting_risk = model_evaluation(model, X_train, y_train)

    # Obtener la métrica de exactitud para Optuna
    mean_test_score = df.loc['test_set', 'interval_lower']
    trial.report(mean_test_score, step=0)

    # Verificar si se debe podar el trial
    if trial.should_prune():
        raise optuna.TrialPruned()

    return mean_test_score, df, overfitting_risk

# %%
def run_optimization(classifiers, n_trials=10, output_csv="resultados_trials.csv", X_train=None, y_train=None):
    """
    Función para ejecutar la optimización con múltiples clasificadores y almacenar resultados.
    
    Parámetros:
    - classifiers: lista de nombres de clasificadores o un solo clasificador.
    - n_trials: número de trials para cada optimización.
    - output_csv: nombre del archivo CSV donde se almacenarán los resultados.
    """
    
    if isinstance(classifiers, str):  # Convertir en lista si es un solo clasificador
        classifiers = [classifiers]

    all_results = {}

    # Iterar sobre cada clasificador
    for classifier in classifiers:
        # Crear un nuevo estudio para cada clasificador
        study = optuna.create_study(
            direction="maximize",                   # Segun la metrica a mejorar su valor se puede maximizar o minimizar
            sampler=optuna.samplers.RandomSampler(),
        )
        
        # Optimizar el estudio con la función objetivo
        study.optimize(lambda trial: objective(classifier, trial, X_train, y_train)[0], n_trials=n_trials)
         
        # Crear un diccionario específico para este clasificador
        classifier_results = []
        
        # Guardar cada trial del estudio en el diccionario
        for trial in study.trials:
            _, metrics, overfitting_risk = objective(classifier, trial, X_train, y_train)
            
            # Guardar todos los resultados del trial
            classifier_results.append({
                'trial_number': trial.number,
                'value': trial.value,
                'params': trial.params,
                'metrics': metrics,
                'overfitting_risk': overfitting_risk
            })
        
        # Almacenar los resultados del clasificador actual
        all_results[classifier] = {
            'best_value': study.best_value,
            'best_params': study.best_params,
            'all_trials': classifier_results
        }

    # Convertir los resultados en un DataFrame
    trials = []
    
    for model, metrics in all_results.items():
        all_trials = metrics['all_trials']
        
        for trial in all_trials:
            trial_data = {
                'Model': model,
                'Trial Number': trial['trial_number'],
                'Value': trial['value'],
                'Mean Train Score': trial['metrics']['mean']['train_set'],
                'Mean Test Score': trial['metrics']['mean']['test_set'],
                'Train Std': trial['metrics']['std']['train_set'],
                'Test Std': trial['metrics']['std']['test_set'],
                'Overfitting Risk': trial['overfitting_risk']['overfitting_likelihood'],
                'p_value': round(trial['overfitting_risk']['p_value'], 4)
            }
            
            trial_data.update(trial['params'])
            trials.append(trial_data)
    
    # Convertir a DataFrame y guardar en CSV
    results_df = pd.DataFrame(trials)
    results_df.to_csv(output_csv, index=False)
    print(f"Resultados guardados en '{output_csv}'")

# %%
def update_parameters_trials(classifiers, X_train, y_train, csv_folder="parameters_trials"):
    # Asegurarse de que la carpeta para los CSVs exista
    if not os.path.exists(csv_folder):
        os.makedirs(csv_folder)
    
    for model_name in classifiers:
        csv_file = os.path.join(csv_folder, f"{model_name}_parameters_trials.csv")
        
        # Verificar si el archivo CSV ya existe para ese modelo
        if os.path.exists(csv_file):
            trials_df = pd.read_csv(csv_file)
            print(f"Archivo {csv_file} leído correctamente.")
            
            # Verificar si el CSV tiene registros
            if trials_df.empty:
                print(f"El archivo CSV de {model_name} está vacío.")
            else:
                print(f"El archivo CSV de {model_name} contiene {len(trials_df)} registros previos.")
        else:
            # Si no existe el archivo, crear un nuevo DataFrame con las columnas predeterminadas
            trials_df = pd.DataFrame(columns=["Model", "Trial Number", "Value", "Mean Train Score", 
                                              "Mean Test Score", "Train Std", "Test Std", "Overfitting Risk", 
                                              "p_value", "rf_n_estimators", "rf_max_depth", "rf_min_samples_split", 
                                              "rf_min_samples_leaf", "rf_max_features", "rf_bootstrap", "naive_var_smoothing", 
                                              "gbm_n_estimators", "gbm_learning_rate", "gbm_max_depth", "gbm_min_samples_split", 
                                              "gbm_min_samples_leaf", "gbm_max_features", "knn_n_neighbors", "knn_weights", 
                                              "knn_p", "dt_max_depth", "dt_min_samples_split", "dt_min_samples_leaf", "dt_criterion"])
            print(f"El archivo {csv_file} no existe. Se creará uno nuevo.")
        
        # Filtrar los registros del modelo actual para ver si es necesario hacer optimización
        models_in_csv = trials_df['Model'].unique().tolist()
        print(f"Modelos en el archivo {csv_file}: {models_in_csv}")
        
        # Si el modelo no está en el CSV, realizar optimización
        if model_name not in models_in_csv:
            print(f"Ejecutando optimización para {model_name}...")
            # Ejecutar la optimización para el modelo faltante
            run_optimization(classifiers=[model_name], n_trials= 10, output_csv=csv_file, X_train=X_train, y_train=y_train)
            
            # Leer el CSV actualizado después de la optimización
            trials_df_new = pd.read_csv(csv_file)
            print(f"Resultados de optimización para {model_name} añadidos al archivo.")
            
            # Asegurarse de no duplicar los registros
            trials_df = pd.concat([trials_df, trials_df_new], ignore_index=True).drop_duplicates(subset=["Model", "Trial Number"])

        # Verificar si todos los modelos de la lista ya están en el CSV
        if all(model in trials_df['Model'].unique() for model in classifiers):
            # Añadir la fila de 'Busqueda finalizada' si no existe
            if 'Busqueda finalizada' not in trials_df['Model'].values:
                final_row = pd.DataFrame([['Busqueda finalizada'] + [None] * (trials_df.shape[1] - 1)],
                                         columns=trials_df.columns)
                # Eliminar las columnas vacías o todas-NaN en final_row
                final_row = final_row.dropna(axis=1, how='all')

                # Concatenar la fila sin los valores vacíos
                trials_df = pd.concat([trials_df, final_row], ignore_index=True)
                print(f"Fila 'Busqueda finalizada' añadida al archivo.")

        # Guardar los resultados en el CSV para el modelo actual
        trials_df.to_csv(csv_file, mode='a', header=False, index=False)  # Agregar sin sobrescribir encabezados
        print(f"Resultados agregados al archivo {csv_file}.")

# %%
# Lista de clasificadores
classifiers = [] # Saque 'logit', 'Naive', 'Knn','gbm', 'RF','dt', 'svc'  por costos computacionales

# %%
update_parameters_trials(classifiers, 
                         X_train = X_train, 
                         y_train= y_train, 
#                         csv_file="../Medical Appointment No Show/parameters_trials.csv"
                        )

# %% [markdown]
# [I 2024-11-07 15:22:31,901] Trial 3 finished with value: 0.1889558984430899 and parameters: {'knn_n_neighbors': 3, 'knn_weights': 'uniform', 'knn_p': 2}. Best is trial 3 with value: 0.1889558984430899.

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import lightgbm as lgb

# %%
# Initialize the LightGBM model
lgbm_classifier = lgb.LGBMClassifier(random_state=42)

# %%
print(X_train.columns.tolist())
# Out:
# ['Hipertension', 'SMS_received', 'FirstTimeAppointment', 'RiesgoGeneral', 'Gender_M', 'Cluster_3', 'Cluster_4', 'WaitingTime__15_0_31_0_', 'WaitingTime__31_0_50_0_', 'WaitingTime__50_0_inf_', 'WaitingTime__7_0_15_0_', 'ScheduledPeriod_Tarde', 'Age_group_Adultos_mayores_60_79_', 'Age_group_Adultos_medios_40_59_', 'Age_group_J_venes_adultos_20_39_']

# %%
X_train.columns = X_train.columns.str.replace(r'[^A-Za-z0-9_]+', '_', regex=True)

# %%
X_test.columns = X_test.columns.str.replace(r'[^A-Za-z0-9_]+', '_', regex=True)

# %%
print(X_train.columns.tolist())
# Out:
# ['Hipertension', 'SMS_received', 'FirstTimeAppointment', 'RiesgoGeneral', 'Gender_M', 'Cluster_3', 'Cluster_4', 'WaitingTime__15_0_31_0_', 'WaitingTime__31_0_50_0_', 'WaitingTime__50_0_inf_', 'WaitingTime__7_0_15_0_', 'ScheduledPeriod_Tarde', 'Age_group_Adultos_mayores_60_79_', 'Age_group_Adultos_medios_40_59_', 'Age_group_J_venes_adultos_20_39_']

# %%
lgbm_classifier.fit(X_train, y_train)
# Out:
# LGBMClassifier(random_state=42)

# %% [markdown]
# from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %%
y_pred = lgbm_classifier.predict(X_test)

# %%
y_pred_proba = lgbm_classifier.predict_proba(X_test)[:, 1]

# %%
# Calculate metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred_proba)

# %%
# Print the metrics
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
print(f"ROC AUC Score: {roc_auc}")
# Out:
# Accuracy: 0.7931596091205212
# Precision: 0.3835616438356164
# Recall: 0.006147091108671789
# F1 Score: 0.012100259291270527
# ROC AUC Score: 0.6805944077924135

# %%
def objective(trial):
    # Define the search space using trial.suggest_ methods
    param = {
        'objective': 'binary',
        'metric': 'auc',
        'verbosity': -1,
        'boosting_type': 'gbdt',
        'num_leaves': trial.suggest_int('num_leaves', 20, 100),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
        'n_estimators': trial.suggest_int('n_estimators', 50, 1000),
        'min_child_samples': trial.suggest_int('min_child_samples', 20, 500),
        'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'reg_alpha': trial.suggest_float('reg_alpha', 0, 1.0),
        'reg_lambda': trial.suggest_float('reg_lambda', 0, 1.0),
        'random_state': 42,
        'class_weight': 'balanced'  # Address class imbalance
    }
    
    # Create and fit the model
    model = lgb.LGBMClassifier(**param)
    model.fit(X_train, y_train, eval_set=[(X_test, y_test)])
    
    # Predict and calculate ROC AUC Score
    preds = model.predict_proba(X_test)[:, 1]
    roc_auc = roc_auc_score(y_test, preds)
    
    return roc_auc

# %%
study = optuna.create_study(direction='maximize')
# Out:
# [I 2024-11-07 18:43:24,669] A new study created in memory with name: no-name-fe5e7327-2a2e-444b-b6a6-279194aa9a06

# %%
study.optimize(objective, n_trials=100)  # You can adjust n_trials to your needs
# Out:
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:43:26,192] Trial 0 finished with value: 0.6813413019052378 and parameters: {'num_leaves': 91, 'max_depth': 3, 'learning_rate': 0.14499469902293008, 'n_estimators': 468, 'min_child_samples': 432, 'min_child_weight': 1.007971582943665e-05, 'subsample': 0.9199601264831743, 'colsample_bytree': 0.987055955522059, 'reg_alpha': 0.09596950942989124, 'reg_lambda': 0.1722050778664882}. Best is trial 0 with value: 0.6813413019052378.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:43:29,841] Trial 1 finished with value: 0.6761278112362695 and parameters: {'num_leaves': 48, 'max_depth': 8, 'learning_rate': 0.2780351643432812, 'n_estimators': 861, 'min_child_samples': 485, 'min_child_weight': 0.000100201604087014, 'subsample': 0.6541938942802494, 'colsample_bytree': 0.6102637487913878, 'reg_alpha': 0.07265071807127066, 'reg_lambda': 0.8181196688312955}. Best is trial 0 with value: 0.6813413019052378.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:43:31,021] Trial 2 finished with value: 0.6812226440265515 and parameters: {'num_leaves': 24, 'max_depth': 9, 'learning_rate': 0.0851232494386584, 'n_estimators': 406, 'min_child_samples': 95, 'min_child_weight': 6.037521987471462e-05, 'subsample': 0.7218849171975736, 'colsample_bytree': 0.5942307956893407, 'reg_alpha': 0.9227083405081795, 'reg_lambda': 0.9085771590500356}. Best is trial 0 with value: 0.6813413019052378.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:43:33,426] Trial 3 finished with value: 0.680721153422135 and parameters: {'num_leaves': 53, 'max_depth': 10, 'learning_rate': 0.05812958934430727, 'n_estimators': 578, 'min_child_samples': 467, 'min_child_weight': 0.0001370077268152104, 'subsample': 0.6048452882890567, 'colsample_bytree': 0.5961500660483043, 'reg_alpha': 0.33294204694342144, 'reg_lambda': 0.46630924597686707}. Best is trial 0 with value: 0.6813413019052378.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:43:34,845] Trial 4 finished with value: 0.6801077853892432 and parameters: {'num_leaves': 75, 'max_depth': 6, 'learning_rate': 0.2961745945677886, 'n_estimators': 786, 'min_child_samples': 90, 'min_child_weight': 2.7070111792384442e-05, 'subsample': 0.8323798985187268, 'colsample_bytree': 0.6824712044067069, 'reg_alpha': 0.9566395927141171, 'reg_lambda': 0.20876368571215242}. Best is trial 0 with value: 0.6813413019052378.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:43:35,520] Trial 5 finished with value: 0.6805829798564959 and parameters: {'num_leaves': 35, 'max_depth': 5, 'learning_rate': 0.17814838079062742, 'n_estimators': 180, 'min_child_samples': 296, 'min_child_weight': 0.0013217872107135207, 'subsample': 0.8455789325468848, 'colsample_bytree': 0.6448442317133866, 'reg_alpha': 0.09403583791358194, 'reg_lambda': 0.9699548332694562}. Best is trial 0 with value: 0.6813413019052378.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:43:38,632] Trial 6 finished with value: 0.6742550558921144 and parameters: {'num_leaves': 71, 'max_depth': 10, 'learning_rate': 0.14633126752103356, 'n_estimators': 574, 'min_child_samples': 432, 'min_child_weight': 0.0005050969971851669, 'subsample': 0.6320954128372669, 'colsample_bytree': 0.9687444018910073, 'reg_alpha': 0.012927545952065689, 'reg_lambda': 0.9826106377468812}. Best is trial 0 with value: 0.6813413019052378.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:43:40,623] Trial 7 finished with value: 0.6809297961317531 and parameters: {'num_leaves': 34, 'max_depth': 3, 'learning_rate': 0.2729536636858908, 'n_estimators': 940, 'min_child_samples': 165, 'min_child_weight': 0.005458494544308456, 'subsample': 0.7867756538106317, 'colsample_bytree': 0.5425391388559505, 'reg_alpha': 0.7411863016827357, 'reg_lambda': 0.051240256782965066}. Best is trial 0 with value: 0.6813413019052378.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:43:41,304] Trial 8 finished with value: 0.6810322534882569 and parameters: {'num_leaves': 33, 'max_depth': 5, 'learning_rate': 0.1342523034936959, 'n_estimators': 195, 'min_child_samples': 276, 'min_child_weight': 0.0014820514546597845, 'subsample': 0.5393777579109879, 'colsample_bytree': 0.6089397142059251, 'reg_alpha': 0.4544546265596062, 'reg_lambda': 0.3539278466478537}. Best is trial 0 with value: 0.6813413019052378.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:43:42,071] Trial 9 finished with value: 0.6816020990372322 and parameters: {'num_leaves': 96, 'max_depth': 9, 'learning_rate': 0.15450657579496965, 'n_estimators': 285, 'min_child_samples': 141, 'min_child_weight': 0.0026691421668531582, 'subsample': 0.6497714733503818, 'colsample_bytree': 0.5419697896138258, 'reg_alpha': 0.9996962884388568, 'reg_lambda': 0.6785156406632427}. Best is trial 9 with value: 0.6816020990372322.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:43:42,941] Trial 10 finished with value: 0.6783759308028785 and parameters: {'num_leaves': 98, 'max_depth': 8, 'learning_rate': 0.20848844573990674, 'n_estimators': 307, 'min_child_samples': 20, 'min_child_weight': 0.009765757245838221, 'subsample': 0.5167745141381157, 'colsample_bytree': 0.8088166437153125, 'reg_alpha': 0.701015228202968, 'reg_lambda': 0.6773468839665826}. Best is trial 9 with value: 0.6816020990372322.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:43:44,075] Trial 11 finished with value: 0.681645709091539 and parameters: {'num_leaves': 100, 'max_depth': 3, 'learning_rate': 0.10396334127615017, 'n_estimators': 459, 'min_child_samples': 366, 'min_child_weight': 1.748681816515471e-05, 'subsample': 0.9702803089544887, 'colsample_bytree': 0.8577406259570198, 'reg_alpha': 0.2604911310847864, 'reg_lambda': 0.6298563843959799}. Best is trial 11 with value: 0.681645709091539.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:43:47,088] Trial 12 finished with value: 0.6814279965915101 and parameters: {'num_leaves': 86, 'max_depth': 7, 'learning_rate': 0.013888418785832093, 'n_estimators': 688, 'min_child_samples': 352, 'min_child_weight': 0.00042596020033419327, 'subsample': 0.9791698803784137, 'colsample_bytree': 0.8317322788360985, 'reg_alpha': 0.29118488222937555, 'reg_lambda': 0.6914056836915929}. Best is trial 11 with value: 0.681645709091539.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:43:47,405] Trial 13 finished with value: 0.6806831541278273 and parameters: {'num_leaves': 100, 'max_depth': 4, 'learning_rate': 0.10034308281963791, 'n_estimators': 52, 'min_child_samples': 199, 'min_child_weight': 0.0013062744086204338, 'subsample': 0.7159862522648541, 'colsample_bytree': 0.8818360345824902, 'reg_alpha': 0.6318693824801898, 'reg_lambda': 0.6369402994627565}. Best is trial 11 with value: 0.681645709091539.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:43:48,955] Trial 14 finished with value: 0.6781478599766976 and parameters: {'num_leaves': 80, 'max_depth': 7, 'learning_rate': 0.21485258582527375, 'n_estimators': 375, 'min_child_samples': 355, 'min_child_weight': 0.004024384994192286, 'subsample': 0.9719891474015508, 'colsample_bytree': 0.7278845204154691, 'reg_alpha': 0.27662785805457224, 'reg_lambda': 0.5277174310710366}. Best is trial 11 with value: 0.681645709091539.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:43:50,158] Trial 15 finished with value: 0.6814227798982669 and parameters: {'num_leaves': 64, 'max_depth': 9, 'learning_rate': 0.08701303674545807, 'n_estimators': 265, 'min_child_samples': 205, 'min_child_weight': 1.0523069243700813e-05, 'subsample': 0.9004774984729571, 'colsample_bytree': 0.5023535141983496, 'reg_alpha': 0.440019064415723, 'reg_lambda': 0.7934857433471932}. Best is trial 11 with value: 0.681645709091539.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:43:50,655] Trial 16 finished with value: 0.6811855767313963 and parameters: {'num_leaves': 90, 'max_depth': 6, 'learning_rate': 0.19836850187689803, 'n_estimators': 93, 'min_child_samples': 358, 'min_child_weight': 3.402052358010774e-05, 'subsample': 0.6784638649848465, 'colsample_bytree': 0.8721386995037734, 'reg_alpha': 0.8509957419642575, 'reg_lambda': 0.49962608926783536}. Best is trial 11 with value: 0.681645709091539.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:43:52,227] Trial 17 finished with value: 0.6813419774482476 and parameters: {'num_leaves': 82, 'max_depth': 4, 'learning_rate': 0.035262084663457344, 'n_estimators': 526, 'min_child_samples': 131, 'min_child_weight': 0.00018272960634463787, 'subsample': 0.7671082651668101, 'colsample_bytree': 0.7665694687397054, 'reg_alpha': 0.5881505165695518, 'reg_lambda': 0.37361051385509636}. Best is trial 11 with value: 0.681645709091539.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:43:54,301] Trial 18 finished with value: 0.6780701850406129 and parameters: {'num_leaves': 65, 'max_depth': 8, 'learning_rate': 0.11263291591117676, 'n_estimators': 678, 'min_child_samples': 226, 'min_child_weight': 0.0006702387607686421, 'subsample': 0.5719290321789465, 'colsample_bytree': 0.9292071745028334, 'reg_alpha': 0.24136391623697484, 'reg_lambda': 0.5995074073887063}. Best is trial 11 with value: 0.681645709091539.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:43:55,203] Trial 19 finished with value: 0.6795237659471154 and parameters: {'num_leaves': 94, 'max_depth': 9, 'learning_rate': 0.23002259054684787, 'n_estimators': 347, 'min_child_samples': 32, 'min_child_weight': 0.0027840553022162795, 'subsample': 0.8296788874167457, 'colsample_bytree': 0.7123059547064927, 'reg_alpha': 0.8292880924102373, 'reg_lambda': 0.7659350859689439}. Best is trial 11 with value: 0.681645709091539.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:43:56,421] Trial 20 finished with value: 0.6815939800110576 and parameters: {'num_leaves': 54, 'max_depth': 5, 'learning_rate': 0.17697643893440412, 'n_estimators': 456, 'min_child_samples': 304, 'min_child_weight': 0.00019577521506338106, 'subsample': 0.892302525693456, 'colsample_bytree': 0.7829131409979956, 'reg_alpha': 0.5449062749906277, 'reg_lambda': 0.38213081464216503}. Best is trial 11 with value: 0.681645709091539.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:43:57,685] Trial 21 finished with value: 0.6810724733174585 and parameters: {'num_leaves': 52, 'max_depth': 4, 'learning_rate': 0.16781501726308978, 'n_estimators': 424, 'min_child_samples': 315, 'min_child_weight': 0.0003022408884322404, 'subsample': 0.9174201034270791, 'colsample_bytree': 0.7700617163801197, 'reg_alpha': 0.5385614816708539, 'reg_lambda': 0.38281029718492876}. Best is trial 11 with value: 0.681645709091539.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:43:58,497] Trial 22 finished with value: 0.6804055747560586 and parameters: {'num_leaves': 44, 'max_depth': 5, 'learning_rate': 0.12273865886254348, 'n_estimators': 227, 'min_child_samples': 243, 'min_child_weight': 2.3808818138035847e-05, 'subsample': 0.8742525835241335, 'colsample_bytree': 0.8205011576294953, 'reg_alpha': 0.3868868770224264, 'reg_lambda': 0.5671162791576831}. Best is trial 11 with value: 0.681645709091539.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:43:59,766] Trial 23 finished with value: 0.6814199276055585 and parameters: {'num_leaves': 61, 'max_depth': 3, 'learning_rate': 0.24635031148436998, 'n_estimators': 490, 'min_child_samples': 392, 'min_child_weight': 5.305300570680485e-05, 'subsample': 0.9492674434432067, 'colsample_bytree': 0.8864515931156125, 'reg_alpha': 0.23657267832788617, 'reg_lambda': 0.2561956856739827}. Best is trial 11 with value: 0.681645709091539.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:44:02,298] Trial 24 finished with value: 0.6770542934542572 and parameters: {'num_leaves': 71, 'max_depth': 6, 'learning_rate': 0.1813061438427483, 'n_estimators': 652, 'min_child_samples': 318, 'min_child_weight': 0.0007428738678931855, 'subsample': 0.7974197326934872, 'colsample_bytree': 0.8011406367130625, 'reg_alpha': 0.1801249270913853, 'reg_lambda': 0.4354333675247508}. Best is trial 11 with value: 0.681645709091539.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:44:03,251] Trial 25 finished with value: 0.6814786748273096 and parameters: {'num_leaves': 57, 'max_depth': 4, 'learning_rate': 0.1598287439481898, 'n_estimators': 308, 'min_child_samples': 393, 'min_child_weight': 1.746557761005368e-05, 'subsample': 0.9409695545091519, 'colsample_bytree': 0.6834700909508761, 'reg_alpha': 0.734262723654525, 'reg_lambda': 0.7380266914991497}. Best is trial 11 with value: 0.681645709091539.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:44:03,772] Trial 26 finished with value: 0.6814500142896112 and parameters: {'num_leaves': 82, 'max_depth': 5, 'learning_rate': 0.050175534702003324, 'n_estimators': 129, 'min_child_samples': 252, 'min_child_weight': 0.00018977511791106003, 'subsample': 0.9910765849308474, 'colsample_bytree': 0.9170289110233646, 'reg_alpha': 0.5135344065137585, 'reg_lambda': 0.8813172517647385}. Best is trial 11 with value: 0.681645709091539.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:44:05,611] Trial 27 finished with value: 0.677962310829974 and parameters: {'num_leaves': 44, 'max_depth': 7, 'learning_rate': 0.07777812955484828, 'n_estimators': 437, 'min_child_samples': 155, 'min_child_weight': 8.231090674887038e-05, 'subsample': 0.8751316357803555, 'colsample_bytree': 0.8519107905162371, 'reg_alpha': 0.17131918870791796, 'reg_lambda': 0.29827959826557715}. Best is trial 11 with value: 0.681645709091539.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:44:06,788] Trial 28 finished with value: 0.6811644535022807 and parameters: {'num_leaves': 95, 'max_depth': 3, 'learning_rate': 0.12241050031370256, 'n_estimators': 547, 'min_child_samples': 285, 'min_child_weight': 0.0003088254573198091, 'subsample': 0.5833037815891484, 'colsample_bytree': 0.7844955905242724, 'reg_alpha': 0.9966354370992501, 'reg_lambda': 0.5932510434570459}. Best is trial 11 with value: 0.681645709091539.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:44:07,980] Trial 29 finished with value: 0.681400812240389 and parameters: {'num_leaves': 90, 'max_depth': 3, 'learning_rate': 0.18825371313455705, 'n_estimators': 478, 'min_child_samples': 420, 'min_child_weight': 0.0026232698699424966, 'subsample': 0.6976795138802854, 'colsample_bytree': 0.9871084959662082, 'reg_alpha': 0.3652977761610252, 'reg_lambda': 0.05346383746664973}. Best is trial 11 with value: 0.681645709091539.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:44:09,873] Trial 30 finished with value: 0.6813908167058533 and parameters: {'num_leaves': 87, 'max_depth': 4, 'learning_rate': 0.14327870599961404, 'n_estimators': 615, 'min_child_samples': 328, 'min_child_weight': 1.1926414477338328e-05, 'subsample': 0.8910179190937643, 'colsample_bytree': 0.7382450310911315, 'reg_alpha': 0.8050930997842833, 'reg_lambda': 0.13418323624501083}. Best is trial 11 with value: 0.681645709091539.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:44:10,824] Trial 31 finished with value: 0.6816605960578688 and parameters: {'num_leaves': 56, 'max_depth': 4, 'learning_rate': 0.16140963213892773, 'n_estimators': 304, 'min_child_samples': 387, 'min_child_weight': 1.6173643168207162e-05, 'subsample': 0.9434295123828589, 'colsample_bytree': 0.685862974145234, 'reg_alpha': 0.6684642657111144, 'reg_lambda': 0.7359637069955701}. Best is trial 31 with value: 0.6816605960578688.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:44:12,144] Trial 32 finished with value: 0.6811157956404832 and parameters: {'num_leaves': 56, 'max_depth': 5, 'learning_rate': 0.1587965613829035, 'n_estimators': 324, 'min_child_samples': 408, 'min_child_weight': 4.181006260498802e-05, 'subsample': 0.9412836272243339, 'colsample_bytree': 0.5339285512671408, 'reg_alpha': 0.6419703796983259, 'reg_lambda': 0.6933230352635371}. Best is trial 31 with value: 0.6816605960578688.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:44:13,006] Trial 33 finished with value: 0.6812331962585677 and parameters: {'num_leaves': 47, 'max_depth': 3, 'learning_rate': 0.10726524430445403, 'n_estimators': 255, 'min_child_samples': 461, 'min_child_weight': 1.8347496060657387e-05, 'subsample': 0.9991185183407484, 'colsample_bytree': 0.6375580234500388, 'reg_alpha': 0.5730405504177953, 'reg_lambda': 0.8322148896986211}. Best is trial 31 with value: 0.6816605960578688.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:44:14,401] Trial 34 finished with value: 0.6815883379759192 and parameters: {'num_leaves': 68, 'max_depth': 4, 'learning_rate': 0.1394241065293493, 'n_estimators': 392, 'min_child_samples': 494, 'min_child_weight': 8.783892223355188e-05, 'subsample': 0.9607425658612893, 'colsample_bytree': 0.5606066338965308, 'reg_alpha': 0.4501296860412295, 'reg_lambda': 0.5404039078773817}. Best is trial 31 with value: 0.6816605960578688.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:44:15,635] Trial 35 finished with value: 0.6806036965088 and parameters: {'num_leaves': 40, 'max_depth': 6, 'learning_rate': 0.2373336768873457, 'n_estimators': 469, 'min_child_samples': 361, 'min_child_weight': 1.61822221207379e-05, 'subsample': 0.9260220547975274, 'colsample_bytree': 0.6922846130954098, 'reg_alpha': 0.8943916834912313, 'reg_lambda': 0.4559715211448364}. Best is trial 31 with value: 0.6816605960578688.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:44:16,752] Trial 36 finished with value: 0.6803982438633954 and parameters: {'num_leaves': 24, 'max_depth': 5, 'learning_rate': 0.1713553130019286, 'n_estimators': 375, 'min_child_samples': 79, 'min_child_weight': 5.7664147133571916e-05, 'subsample': 0.6618638239089158, 'colsample_bytree': 0.6327891418472485, 'reg_alpha': 0.6720414527441474, 'reg_lambda': 0.8526596513101017}. Best is trial 31 with value: 0.6816605960578688.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:44:18,463] Trial 37 finished with value: 0.681394044300234 and parameters: {'num_leaves': 77, 'max_depth': 10, 'learning_rate': 0.19200049894785232, 'n_estimators': 735, 'min_child_samples': 462, 'min_child_weight': 0.00013643319899496966, 'subsample': 0.7357435351396855, 'colsample_bytree': 0.5779560307838385, 'reg_alpha': 0.7820868080715102, 'reg_lambda': 0.6418116428526126}. Best is trial 31 with value: 0.6816605960578688.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:44:19,347] Trial 38 finished with value: 0.6804492223405325 and parameters: {'num_leaves': 52, 'max_depth': 9, 'learning_rate': 0.07037005932743022, 'n_estimators': 183, 'min_child_samples': 294, 'min_child_weight': 3.074349287975199e-05, 'subsample': 0.8375870116374375, 'colsample_bytree': 0.915856238342315, 'reg_alpha': 0.9084719354665778, 'reg_lambda': 0.9252153746587424}. Best is trial 31 with value: 0.6816605960578688.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:44:20,054] Trial 39 finished with value: 0.6816839773520452 and parameters: {'num_leaves': 60, 'max_depth': 3, 'learning_rate': 0.15125101427471002, 'n_estimators': 257, 'min_child_samples': 378, 'min_child_weight': 0.00895602638610504, 'subsample': 0.6096742864089387, 'colsample_bytree': 0.8470086910584412, 'reg_alpha': 0.029029221369254482, 'reg_lambda': 0.7252700316840223}. Best is trial 39 with value: 0.6816839773520452.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:44:20,534] Trial 40 finished with value: 0.6809306092853762 and parameters: {'num_leaves': 59, 'max_depth': 3, 'learning_rate': 0.1300138237029462, 'n_estimators': 145, 'min_child_samples': 390, 'min_child_weight': 0.007655091684526252, 'subsample': 0.6298691128832046, 'colsample_bytree': 0.9530497920818064, 'reg_alpha': 0.018962282132450096, 'reg_lambda': 0.7373973361990122}. Best is trial 39 with value: 0.6816839773520452.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:44:21,315] Trial 41 finished with value: 0.6812289616046998 and parameters: {'num_leaves': 63, 'max_depth': 3, 'learning_rate': 0.15304169340447496, 'n_estimators': 276, 'min_child_samples': 376, 'min_child_weight': 0.0021272458470020894, 'subsample': 0.6328998317077627, 'colsample_bytree': 0.8619930435253242, 'reg_alpha': 0.1080620939799683, 'reg_lambda': 0.7297803873563902}. Best is trial 39 with value: 0.6816839773520452.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:44:22,117] Trial 42 finished with value: 0.6812032659502116 and parameters: {'num_leaves': 54, 'max_depth': 4, 'learning_rate': 0.2081060009429863, 'n_estimators': 236, 'min_child_samples': 336, 'min_child_weight': 0.005495226859387248, 'subsample': 0.5983369380060984, 'colsample_bytree': 0.8352234796784218, 'reg_alpha': 0.15796263232811864, 'reg_lambda': 0.6271507380057203}. Best is trial 39 with value: 0.6816839773520452.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:44:23,486] Trial 43 finished with value: 0.6818071701259368 and parameters: {'num_leaves': 49, 'max_depth': 3, 'learning_rate': 0.09769521752980331, 'n_estimators': 433, 'min_child_samples': 438, 'min_child_weight': 0.004828478000906503, 'subsample': 0.5237556510132434, 'colsample_bytree': 0.7863045446158086, 'reg_alpha': 0.41489420908539315, 'reg_lambda': 0.790957283213483}. Best is trial 43 with value: 0.6818071701259368.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:44:24,574] Trial 44 finished with value: 0.6813945572125193 and parameters: {'num_leaves': 39, 'max_depth': 3, 'learning_rate': 0.0891945273292482, 'n_estimators': 347, 'min_child_samples': 446, 'min_child_weight': 0.0051461231998983, 'subsample': 0.5003737091563005, 'colsample_bytree': 0.8454166808384683, 'reg_alpha': 0.05985049187038116, 'reg_lambda': 0.8174501643925886}. Best is trial 43 with value: 0.6818071701259368.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:44:26,475] Trial 45 finished with value: 0.6805474262780852 and parameters: {'num_leaves': 47, 'max_depth': 8, 'learning_rate': 0.05776955975723424, 'n_estimators': 404, 'min_child_samples': 435, 'min_child_weight': 0.009307981413135288, 'subsample': 0.544204710805257, 'colsample_bytree': 0.8949020811681333, 'reg_alpha': 0.38234515598545293, 'reg_lambda': 0.7796640066611242}. Best is trial 43 with value: 0.6818071701259368.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:44:27,445] Trial 46 finished with value: 0.6811965605603354 and parameters: {'num_leaves': 97, 'max_depth': 3, 'learning_rate': 0.09627183313760419, 'n_estimators': 307, 'min_child_samples': 410, 'min_child_weight': 0.0038272732035238496, 'subsample': 0.5449304188209297, 'colsample_bytree': 0.7502618608625045, 'reg_alpha': 0.30447028797746545, 'reg_lambda': 0.9156943996759405}. Best is trial 43 with value: 0.6818071701259368.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:44:28,257] Trial 47 finished with value: 0.6817961174916912 and parameters: {'num_leaves': 72, 'max_depth': 4, 'learning_rate': 0.12273038675109582, 'n_estimators': 219, 'min_child_samples': 444, 'min_child_weight': 0.0065767503778073454, 'subsample': 0.5631716645432419, 'colsample_bytree': 0.659418559223694, 'reg_alpha': 0.48906136041183734, 'reg_lambda': 0.6686429178750906}. Best is trial 43 with value: 0.6818071701259368.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:44:30,849] Trial 48 finished with value: 0.6812252085879781 and parameters: {'num_leaves': 73, 'max_depth': 4, 'learning_rate': 0.1145160873048143, 'n_estimators': 979, 'min_child_samples': 486, 'min_child_weight': 0.0016723254645354178, 'subsample': 0.564506911123278, 'colsample_bytree': 0.7106834844232951, 'reg_alpha': 0.42053583994316895, 'reg_lambda': 0.6655445817273096}. Best is trial 43 with value: 0.6818071701259368.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:44:31,551] Trial 49 finished with value: 0.6821289975648551 and parameters: {'num_leaves': 68, 'max_depth': 4, 'learning_rate': 0.1318965224366834, 'n_estimators': 214, 'min_child_samples': 437, 'min_child_weight': 0.0009983689844907755, 'subsample': 0.5258474899133682, 'colsample_bytree': 0.6665388956241316, 'reg_alpha': 0.5003631461904281, 'reg_lambda': 0.9526730805236401}. Best is trial 49 with value: 0.6821289975648551.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:44:32,275] Trial 50 finished with value: 0.681740109972147 and parameters: {'num_leaves': 68, 'max_depth': 4, 'learning_rate': 0.13001469179753924, 'n_estimators': 201, 'min_child_samples': 445, 'min_child_weight': 0.0010112491855596925, 'subsample': 0.5225664937223856, 'colsample_bytree': 0.6576919636786231, 'reg_alpha': 0.4794205207388622, 'reg_lambda': 0.850266710725858}. Best is trial 49 with value: 0.6821289975648551.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:44:33,097] Trial 51 finished with value: 0.6819385069461147 and parameters: {'num_leaves': 69, 'max_depth': 4, 'learning_rate': 0.1299272403609538, 'n_estimators': 219, 'min_child_samples': 448, 'min_child_weight': 0.0008344344018767373, 'subsample': 0.521738076072052, 'colsample_bytree': 0.6615195263851792, 'reg_alpha': 0.6141704879264821, 'reg_lambda': 0.9977544132973666}. Best is trial 49 with value: 0.6821289975648551.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:44:33,777] Trial 52 finished with value: 0.6819453749667153 and parameters: {'num_leaves': 67, 'max_depth': 4, 'learning_rate': 0.1288764701902408, 'n_estimators': 157, 'min_child_samples': 473, 'min_child_weight': 0.0010043262712839203, 'subsample': 0.5223665660560186, 'colsample_bytree': 0.6568581782955263, 'reg_alpha': 0.4959765036052635, 'reg_lambda': 0.9986542303992504}. Best is trial 49 with value: 0.6821289975648551.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:44:34,108] Trial 53 finished with value: 0.6811085710832938 and parameters: {'num_leaves': 69, 'max_depth': 4, 'learning_rate': 0.12799296057545612, 'n_estimators': 68, 'min_child_samples': 476, 'min_child_weight': 0.0010770722907988016, 'subsample': 0.52726182355479, 'colsample_bytree': 0.654099905037825, 'reg_alpha': 0.5022280826822498, 'reg_lambda': 0.9907014430449347}. Best is trial 49 with value: 0.6821289975648551.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:44:34,668] Trial 54 finished with value: 0.6815584889829255 and parameters: {'num_leaves': 78, 'max_depth': 4, 'learning_rate': 0.13773245375604581, 'n_estimators': 133, 'min_child_samples': 447, 'min_child_weight': 0.0009249462713036037, 'subsample': 0.5004849386828054, 'colsample_bytree': 0.6597167507679919, 'reg_alpha': 0.4754487043190395, 'reg_lambda': 0.9491845347085901}. Best is trial 49 with value: 0.6821289975648551.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:44:35,527] Trial 55 finished with value: 0.6812351665923465 and parameters: {'num_leaves': 66, 'max_depth': 5, 'learning_rate': 0.1158725600815536, 'n_estimators': 217, 'min_child_samples': 498, 'min_child_weight': 0.0004367422995153565, 'subsample': 0.5233725636686485, 'colsample_bytree': 0.6092398763515425, 'reg_alpha': 0.590288557909199, 'reg_lambda': 0.878152660854117}. Best is trial 49 with value: 0.6821289975648551.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:44:36,195] Trial 56 finished with value: 0.6815971450551597 and parameters: {'num_leaves': 73, 'max_depth': 5, 'learning_rate': 0.1016600334044902, 'n_estimators': 163, 'min_child_samples': 435, 'min_child_weight': 0.0006468882411005569, 'subsample': 0.5533069627344758, 'colsample_bytree': 0.6260063169602913, 'reg_alpha': 0.41010431382723256, 'reg_lambda': 0.9581008005239616}. Best is trial 49 with value: 0.6821289975648551.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:44:36,609] Trial 57 finished with value: 0.6807781742561942 and parameters: {'num_leaves': 75, 'max_depth': 4, 'learning_rate': 0.091337983132077, 'n_estimators': 99, 'min_child_samples': 471, 'min_child_weight': 0.0018370893374968695, 'subsample': 0.5208645899453628, 'colsample_bytree': 0.656638119611135, 'reg_alpha': 0.6125297208475659, 'reg_lambda': 0.9851080210852012}. Best is trial 49 with value: 0.6821289975648551.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:44:37,381] Trial 58 finished with value: 0.6813868259980725 and parameters: {'num_leaves': 68, 'max_depth': 4, 'learning_rate': 0.07127127934495633, 'n_estimators': 215, 'min_child_samples': 419, 'min_child_weight': 0.0012449147467242531, 'subsample': 0.5821279430131896, 'colsample_bytree': 0.7061431733818817, 'reg_alpha': 0.546457269372933, 'reg_lambda': 0.8748297812120251}. Best is trial 49 with value: 0.6821289975648551.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:44:38,272] Trial 59 finished with value: 0.6809560672488054 and parameters: {'num_leaves': 62, 'max_depth': 6, 'learning_rate': 0.13250413667328806, 'n_estimators': 189, 'min_child_samples': 449, 'min_child_weight': 0.000535554263587443, 'subsample': 0.5597622162526016, 'colsample_bytree': 0.6660756602063994, 'reg_alpha': 0.33862570405091447, 'reg_lambda': 0.9326109084423219}. Best is trial 49 with value: 0.6821289975648551.
# ...
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:44:55,927] Trial 80 finished with value: 0.6815692101006939 and parameters: {'num_leaves': 85, 'max_depth': 4, 'learning_rate': 0.09625198072073249, 'n_estimators': 134, 'min_child_samples': 456, 'min_child_weight': 0.004628050912633202, 'subsample': 0.708737457806178, 'colsample_bytree': 0.6358481935633078, 'reg_alpha': 0.7131051986939028, 'reg_lambda': 0.9999270654570818}. Best is trial 49 with value: 0.6821289975648551.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:44:56,988] Trial 81 finished with value: 0.6816226530588119 and parameters: {'num_leaves': 68, 'max_depth': 4, 'learning_rate': 0.13879362355348102, 'n_estimators': 258, 'min_child_samples': 419, 'min_child_weight': 0.0012283023695762907, 'subsample': 0.8131183928496857, 'colsample_bytree': 0.6587483003644512, 'reg_alpha': 0.7854816415807712, 'reg_lambda': 0.8140062451712657}. Best is trial 49 with value: 0.6821289975648551.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:44:57,897] Trial 82 finished with value: 0.681771485191941 and parameters: {'num_leaves': 72, 'max_depth': 4, 'learning_rate': 0.14328888810749776, 'n_estimators': 243, 'min_child_samples': 427, 'min_child_weight': 0.0021207192869138174, 'subsample': 0.8609850967422847, 'colsample_bytree': 0.646145073346667, 'reg_alpha': 0.7436963798320044, 'reg_lambda': 0.8351399597269487}. Best is trial 49 with value: 0.6821289975648551.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:44:58,747] Trial 83 finished with value: 0.6815727754665797 and parameters: {'num_leaves': 75, 'max_depth': 4, 'learning_rate': 0.15576576558879196, 'n_estimators': 189, 'min_child_samples': 442, 'min_child_weight': 0.0022826716467704983, 'subsample': 0.855392577696003, 'colsample_bytree': 0.6176430568086018, 'reg_alpha': 0.7496504168233598, 'reg_lambda': 0.9655650308505147}. Best is trial 49 with value: 0.6821289975648551.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:44:59,648] Trial 84 finished with value: 0.6818207247713303 and parameters: {'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.12601535851309478, 'n_estimators': 286, 'min_child_samples': 369, 'min_child_weight': 0.003315843091639633, 'subsample': 0.8540219156023167, 'colsample_bytree': 0.6381011982679224, 'reg_alpha': 0.52849290472939, 'reg_lambda': 0.7587282774599696}. Best is trial 49 with value: 0.6821289975648551.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:45:00,688] Trial 85 finished with value: 0.6809339119400913 and parameters: {'num_leaves': 66, 'max_depth': 5, 'learning_rate': 0.1257793929684769, 'n_estimators': 286, 'min_child_samples': 471, 'min_child_weight': 0.0032432121174079645, 'subsample': 0.8591308805989633, 'colsample_bytree': 0.6007808511664589, 'reg_alpha': 0.4405489301671812, 'reg_lambda': 0.898810065767024}. Best is trial 49 with value: 0.6821289975648551.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:45:01,389] Trial 86 finished with value: 0.6818764445595926 and parameters: {'num_leaves': 73, 'max_depth': 4, 'learning_rate': 0.11623868621034508, 'n_estimators': 211, 'min_child_samples': 430, 'min_child_weight': 0.0014906781287011366, 'subsample': 0.8266329338370049, 'colsample_bytree': 0.646070631528214, 'reg_alpha': 0.8755552568918135, 'reg_lambda': 0.7569873854557856}. Best is trial 49 with value: 0.6821289975648551.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:45:02,217] Trial 87 finished with value: 0.6815371968680575 and parameters: {'num_leaves': 72, 'max_depth': 5, 'learning_rate': 0.11697590276306892, 'n_estimators': 226, 'min_child_samples': 427, 'min_child_weight': 0.0020268440707278132, 'subsample': 0.8756340471413407, 'colsample_bytree': 0.6296238677207838, 'reg_alpha': 0.8269475540829638, 'reg_lambda': 0.7656463510219479}. Best is trial 49 with value: 0.6821289975648551.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:45:03,327] Trial 88 finished with value: 0.6817695461333011 and parameters: {'num_leaves': 79, 'max_depth': 4, 'learning_rate': 0.08150516101703996, 'n_estimators': 371, 'min_child_samples': 268, 'min_child_weight': 0.0014546401134124048, 'subsample': 0.8302038046040365, 'colsample_bytree': 0.6460529612641213, 'reg_alpha': 0.8752850256932316, 'reg_lambda': 0.689459977171601}. Best is trial 49 with value: 0.6821289975648551.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:45:05,150] Trial 89 finished with value: 0.6817370950487138 and parameters: {'num_leaves': 82, 'max_depth': 4, 'learning_rate': 0.105188866390806, 'n_estimators': 594, 'min_child_samples': 367, 'min_child_weight': 0.002584225227893974, 'subsample': 0.8171998868065142, 'colsample_bytree': 0.5673936461881787, 'reg_alpha': 0.6547444135853554, 'reg_lambda': 0.5978744639211513}. Best is trial 49 with value: 0.6821289975648551.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:45:06,247] Trial 90 finished with value: 0.6814485255929782 and parameters: {'num_leaves': 64, 'max_depth': 4, 'learning_rate': 0.1449069806445282, 'n_estimators': 442, 'min_child_samples': 396, 'min_child_weight': 0.003092845640411437, 'subsample': 0.7495861085909736, 'colsample_bytree': 0.6868105585087163, 'reg_alpha': 0.8738865884433844, 'reg_lambda': 0.747742790095807}. Best is trial 49 with value: 0.6821289975648551.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:45:07,298] Trial 91 finished with value: 0.6814109954257608 and parameters: {'num_leaves': 79, 'max_depth': 4, 'learning_rate': 0.04342430950110682, 'n_estimators': 327, 'min_child_samples': 408, 'min_child_weight': 0.0015257545511465356, 'subsample': 0.8341462858411368, 'colsample_bytree': 0.6395955529072879, 'reg_alpha': 0.8735686350287374, 'reg_lambda': 0.6855964778089226}. Best is trial 49 with value: 0.6821289975648551.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:45:08,395] Trial 92 finished with value: 0.6817455768665049 and parameters: {'num_leaves': 74, 'max_depth': 4, 'learning_rate': 0.08460621361576397, 'n_estimators': 281, 'min_child_samples': 226, 'min_child_weight': 0.0014923502936101858, 'subsample': 0.8491753291097245, 'colsample_bytree': 0.6484696393930818, 'reg_alpha': 0.690052699935742, 'reg_lambda': 0.6188513919624743}. Best is trial 49 with value: 0.6821289975648551.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:45:09,618] Trial 93 finished with value: 0.6817942284732748 and parameters: {'num_leaves': 77, 'max_depth': 4, 'learning_rate': 0.09722241061317308, 'n_estimators': 368, 'min_child_samples': 117, 'min_child_weight': 0.0007946735805236864, 'subsample': 0.7890071271261345, 'colsample_bytree': 0.6644644988470658, 'reg_alpha': 0.9580123384658691, 'reg_lambda': 0.7107805761627872}. Best is trial 49 with value: 0.6821289975648551.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:45:10,746] Trial 94 finished with value: 0.6813508971179897 and parameters: {'num_leaves': 75, 'max_depth': 5, 'learning_rate': 0.09384137424234637, 'n_estimators': 372, 'min_child_samples': 65, 'min_child_weight': 0.0008011592697066852, 'subsample': 0.7913530889941911, 'colsample_bytree': 0.6976467736854399, 'reg_alpha': 0.9783553354183191, 'reg_lambda': 0.7913566897974725}. Best is trial 49 with value: 0.6821289975648551.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:45:12,523] Trial 95 finished with value: 0.6808248993143802 and parameters: {'num_leaves': 76, 'max_depth': 7, 'learning_rate': 0.07096388320385999, 'n_estimators': 420, 'min_child_samples': 115, 'min_child_weight': 0.0004531705754132566, 'subsample': 0.8198343951608298, 'colsample_bytree': 0.6678733447321867, 'reg_alpha': 0.9485375993534091, 'reg_lambda': 0.65777994976443}. Best is trial 49 with value: 0.6821289975648551.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:45:13,336] Trial 96 finished with value: 0.6817527326183879 and parameters: {'num_leaves': 72, 'max_depth': 4, 'learning_rate': 0.1137240301839548, 'n_estimators': 178, 'min_child_samples': 483, 'min_child_weight': 0.0011307286149552535, 'subsample': 0.781452450354382, 'colsample_bytree': 0.6784737909289207, 'reg_alpha': 0.5612846374579343, 'reg_lambda': 0.713172271765157}. Best is trial 49 with value: 0.6821289975648551.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:45:14,442] Trial 97 finished with value: 0.6816868421548096 and parameters: {'num_leaves': 42, 'max_depth': 4, 'learning_rate': 0.12123355519910688, 'n_estimators': 315, 'min_child_samples': 189, 'min_child_weight': 0.0005465616412662561, 'subsample': 0.7641369897004522, 'colsample_bytree': 0.7170084013786048, 'reg_alpha': 0.9171691169327508, 'reg_lambda': 0.74878064630178}. Best is trial 49 with value: 0.6821289975648551.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:45:15,400] Trial 98 finished with value: 0.6812174773735313 and parameters: {'num_leaves': 62, 'max_depth': 5, 'learning_rate': 0.13292835592413693, 'n_estimators': 238, 'min_child_samples': 49, 'min_child_weight': 0.001943998097544348, 'subsample': 0.8060606042933802, 'colsample_bytree': 0.7341689103043395, 'reg_alpha': 0.5141415893944139, 'reg_lambda': 0.9236569029510787}. Best is trial 49 with value: 0.6821289975648551.
# C:\Users\germa\AppData\Local\Temp\ipykernel_22264\3315006726.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-5, 1e-2),
# [I 2024-11-07 18:45:16,035] Trial 99 finished with value: 0.6815658198755887 and parameters: {'num_leaves': 69, 'max_depth': 4, 'learning_rate': 0.10187236528616382, 'n_estimators': 150, 'min_child_samples': 456, 'min_child_weight': 0.0009074654942257856, 'subsample': 0.8706666159727059, 'colsample_bytree': 0.6206303163925521, 'reg_alpha': 0.6022080131477968, 'reg_lambda': 0.6436242429691049}. Best is trial 49 with value: 0.6821289975648551.

# %%
print('Number of finished trials:', len(study.trials))
print('Best trial:', study.best_trial.params)
# Out:
# Number of finished trials: 100
# Best trial: {'num_leaves': 68, 'max_depth': 4, 'learning_rate': 0.1318965224366834, 'n_estimators': 214, 'min_child_samples': 437, 'min_child_weight': 0.0009983689844907755, 'subsample': 0.5258474899133682, 'colsample_bytree': 0.6665388956241316, 'reg_alpha': 0.5003631461904281, 'reg_lambda': 0.9526730805236401}

# %%
params = study.best_trial.params

# %% [markdown]
# Best trial: {'num_leaves': 68, 'max_depth': 4, 'learning_rate': 0.1318965224366834, 'n_estimators': 214, 'min_child_samples': 437, 'min_child_weight': 0.0009983689844907755, 'subsample': 0.5258474899133682, 'colsample_bytree': 0.6665388956241316, 'reg_alpha': 0.5003631461904281, 'reg_lambda': 0.9526730805236401}

# %%
params["random_state"] = 42
params["class_weight"] = "balanced"

# %%
lgbm_classifier = lgb.LGBMClassifier(**params)

# %%
lgbm_classifier.fit(X_train, y_train)
# Out:
# LGBMClassifier(class_weight='balanced', colsample_bytree=0.6665388956241316,
#                learning_rate=0.1318965224366834, max_depth=4,
#                min_child_samples=437, min_child_weight=0.0009983689844907755,
#                n_estimators=214, num_leaves=68, random_state=42,
#                reg_alpha=0.5003631461904281, reg_lambda=0.9526730805236401,
#                subsample=0.5258474899133682)

# %%
y_pred = lgbm_classifier.predict(X = X_train)
y_pred_test = lgbm_classifier.predict(X_test)

# %%
y_pred_proba = lgbm_classifier.predict_proba(X_test)[:, 1]

# %%
# Calculate metrics
accuracy = accuracy_score(y_test, y_pred_test)
precision = precision_score(y_test, y_pred_test)
recall = recall_score(y_test, y_pred_test)
f1 = f1_score(y_test, y_pred_test)
roc_auc = roc_auc_score(y_test, y_pred_test)

# %%
# Print the metrics
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
print(f"ROC AUC Score: {roc_auc}")
# Out:
# Accuracy: 0.6414676076728194
# Precision: 0.3192447972538082
# Recall: 0.6533479692645444
# F1 Score: 0.4289111479426389
# ROC AUC Score: 0.6458659613830842

# %%
resultados(y_train, y_pred)
resultados(y_test, y_pred_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.65      0.75     70658
#            1       0.32      0.65      0.43     17759
#
#     accuracy                           0.65     88417
#    macro avg       0.60      0.65      0.59     88417
# weighted avg       0.77      0.65      0.68     88417
#               precision    recall  f1-score   support
#
#            0       0.88      0.64      0.74     17549
#            1       0.32      0.65      0.43      4555
#
#     accuracy                           0.64     22104
#    macro avg       0.60      0.65      0.58     22104
# weighted avg       0.76      0.64      0.67     22104

# %% [markdown]
# ## Modelo final

# %% [markdown]
# #### Los siguientes parametros se obtuvieron con TPE de Optuna en una corrida en la cual no hay registro. Esto hace notar la aleatoriedad al buscar el mejor conjunto de parametros para determiando modelo, ya que Optuna pudo haber encontrado un maximo local en lugar del minimo global.
# #### De cualquier manera, la precision en la mayoria de los modelos probados cayó dentro del intervalo de confianzapor obtenido del CV del conjunto prueba por lo tanto, no se puede rechazar la hipotesis que dichos modelos no sobreajustan

# %%
model_logist2 = LogisticRegression(
            penalty = 'l2',
            C = 2.5821196041782692,
            solver = 'saga',
            max_iter = 226
        )

# %%
model_logist2.fit(X_train, y_train)

# %%
y_pred = model_logist2.predict(X = X_train)
y_pred_test = model_logist2.predict(X = X_test)
resultados(y_train, y_pred)
resultados(y_test, y_pred_test)

# %%
evaluacion_modelo, riesgo_sobreajuste = model_evaluation(model_logist2, X_train = X_train, y_train = y_train)
evaluacion_modelo

# %%
riesgo_sobreajuste
